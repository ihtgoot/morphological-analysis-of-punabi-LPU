# %%
print("everything will be ok, BUDDY")
# Out:
# everything will be ok, BUDDY

# %%
# !pip install numpy as np
# !pip install pandas as pd
# !pip install matplotlib.pyplot as plt
# !pip install seaborn as sns
# !pip install plotly as py
# !pip install cufflinks 
# !pip install plotly
# !pip install inltk
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py
import cufflinks as cf
from plotly.offline import iplot
import inltk
import nltk
# %matplotlib inline

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_csv('punjabi.txt',sep="\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv('punjabi.txt',sep="\n")
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1013, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1010 del kwds["filepath_or_buffer"]
#    1011 del kwds["sep"]
# ...

# %%
df.head(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [
# ਵੱਡਾ (ਬੇਓਨਸੇ ਗੀਤ)
#
# "ਵੱਡਾ" (ਵੱਡੇ ਅੱਖਰ ਵਿੱਚ ਸ਼ੈਲੀਬੱਧ) ਅਮਰੀਕੀ ਗਾਇਕ ਬਿਓਨਸੇ ਦੁਆਰਾ 2019 ਦੀ ਐਲਬਮ "" ਤੋਂ ਇੱਕ ਗੀਤ ਹੈ ਅਤੇ 2020 ਦੀ ਫਿਲਮ "" ਬਲੈਕ ਇਜ਼ ਕਿੰਗ "" ਵਿੱਚ ਪ੍ਰਦਰਸ਼ਿਤ ਕੀਤਾ ਗਿਆ ਹੈ।
# ਪਿਛੋਕਡ਼.
# ...

# %%
df.isnull()
# Out:
# Empty DataFrame
# Columns: []
# Index: [
# ਵੱਡਾ (ਬੇਓਨਸੇ ਗੀਤ)
#
# "ਵੱਡਾ" (ਵੱਡੇ ਅੱਖਰ ਵਿੱਚ ਸ਼ੈਲੀਬੱਧ) ਅਮਰੀਕੀ ਗਾਇਕ ਬਿਓਨਸੇ ਦੁਆਰਾ 2019 ਦੀ ਐਲਬਮ "" ਤੋਂ ਇੱਕ ਗੀਤ ਹੈ ਅਤੇ 2020 ਦੀ ਫਿਲਮ "" ਬਲੈਕ ਇਜ਼ ਕਿੰਗ "" ਵਿੱਚ ਪ੍ਰਦਰਸ਼ਿਤ ਕੀਤਾ ਗਿਆ ਹੈ।
# ਪਿਛੋਕਡ਼.
# ...

# %%
corpus = " ".join(df.index.astype(str).tolist())
type(corpus), len(corpus), print(corpus[:1000])
# Out:
# ਵੱਡਾ (ਬੇਓਨਸੇ ਗੀਤ)
#
# "ਵੱਡਾ" (ਵੱਡੇ ਅੱਖਰ ਵਿੱਚ ਸ਼ੈਲੀਬੱਧ) ਅਮਰੀਕੀ ਗਾਇਕ ਬਿਓਨਸੇ ਦੁਆਰਾ 2019 ਦੀ ਐਲਬਮ "" ਤੋਂ ਇੱਕ ਗੀਤ ਹੈ ਅਤੇ 2020 ਦੀ ਫਿਲਮ "" ਬਲੈਕ ਇਜ਼ ਕਿੰਗ "" ਵਿੱਚ ਪ੍ਰਦਰਸ਼ਿਤ ਕੀਤਾ ਗਿਆ ਹੈ।
# ਪਿਛੋਕਡ਼.
# ...

# %%
list(df.index[:5])
df.index[0] in corpus
df.index[1] in corpus
# Out:
# True

# %%
import contractions
text = "I can't find Sarah's keys, and she won't be at her brother's house until it's dark."
expanded_text = contractions.fix(text)
print(expanded_text)
# Out:
# I cannot find Sarah's keys, and she will not be at her brother's house until it is dark.

# %%
def cont_to_exp(x):
    if type(x) is str:
        x = x.replace('\\','')
        x = contractions.fix(x)
        return x
    else:
        return x
